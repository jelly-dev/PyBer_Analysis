# %% [markdown]
# # Pyber Challenge

# %% [markdown]
# ### 4.3 Loading and Reading CSV files

# %%
# Add Matplotlib inline magic command
# %matplotlib inline
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd

# File to Load
city_data_to_load = "Resources/city_data.csv"
ride_data_to_load = "Resources/ride_data.csv"

# Read the City and Ride Data
city_data_df = pd.read_csv(city_data_to_load)
ride_data_df = pd.read_csv(ride_data_to_load)

# %% [markdown]
# ### Merge the DataFrames

# %%
# Combine the data into a single dataset
pyber_data_df = pd.merge(ride_data_df, city_data_df, how="left", on=["city", "city"])

# Display the data table for preview
pyber_data_df.head()
# Out:
#                  city                 date   fare        ride_id  \
# 0  Lake Jonathanshire  2019-01-14 10:14:22  13.83  5739410935873
# 1  South Michelleport  2019-03-04 18:24:09  30.24  2343912425577
# 2  Port Samanthamouth  2019-02-24 04:29:00  33.44  2005065760003
# 3          Rodneyfort  2019-02-10 23:22:03  23.44  5149245426178
# 4          South Jack  2019-03-06 04:28:35  34.58  3908451377344
#
#    driver_count   type
# 0             5  Urban
# 1            72  Urban
# 2            57  Urban
# 3            34  Urban
# 4            46  Urban

# %% [markdown]
# ## Deliverable 1: Get a Summary DataFrame

# %%
#  1. Get the total rides for each city type

# Create a dataFrame for each city type

urban_cities_df = pyber_data_df[pyber_data_df["type"]=="Urban"]

suburban_cities_df = pyber_data_df[pyber_data_df["type"]=="Suburban"]

rural_cities_df = pyber_data_df[pyber_data_df["type"]=="Rural"]

# Get total rides

urban_ride_count = urban_cities_df.groupby(["type"]).count()["ride_id"]

suburban_ride_count = suburban_cities_df.groupby(["type"]).count()["ride_id"]

rural_ride_count = rural_cities_df.groupby(["type"]).count()["ride_id"]

# Show count
total_rides = urban_ride_count, suburban_ride_count, rural_ride_count
total_rides
# Out:
# (type
#  Urban    1625
#  Name: ride_id, dtype: int64,
#  type
#  Suburban    625
#  Name: ride_id, dtype: int64,
#  type
#  Rural    125
#  Name: ride_id, dtype: int64)

# %%
# 2. Get the total drivers for each city type

urban_drivers = urban_cities_df.groupby(["type"]).sum()["driver_count"]

suburban_drivers = suburban_cities_df.groupby(["type"]).sum()["driver_count"]

rural_drivers = rural_cities_df.groupby(["type"]).sum()["driver_count"]

# Show total drivers

total_drivers = urban_drivers, suburban_drivers, rural_drivers
total_drivers
# Out:
# (type
#  Urban    59602
#  Name: driver_count, dtype: int64,
#  type
#  Suburban    8570
#  Name: driver_count, dtype: int64,
#  type
#  Rural    537
#  Name: driver_count, dtype: int64)

# %%
#  3. Get the total amount of fares for each city type

urban_fares = urban_cities_df.groupby("type").sum()["fare"]

suburban_fares = suburban_cities_df.groupby("type").sum()["fare"]

rural_fares = rural_cities_df.groupby("type").sum()["fare"]

# Show total fares

total_fares = urban_fares, suburban_fares, rural_fares
total_fares
# Out:
# (type
#  Urban    39854.38
#  Name: fare, dtype: float64,
#  type
#  Suburban    19356.33
#  Name: fare, dtype: float64,
#  type
#  Rural    4327.93
#  Name: fare, dtype: float64)

# %%
#  4. Get the average fare per ride for each city type.

avg_urban_fare = urban_cities_df.groupby("type").sum()["fare"]/ urban_ride_count

avg_suburban_fare = suburban_cities_df.groupby("type").sum()["fare"]/ suburban_ride_count

avg_rural_fare = rural_cities_df.groupby("type").sum()["fare"]/ rural_ride_count

# Show avg fare
avg_fare = avg_urban_fare, avg_suburban_fare, avg_rural_fare
avg_fare
# Out:
# (type
#  Urban    24.525772
#  dtype: float64,
#  type
#  Suburban    30.970128
#  dtype: float64,
#  type
#  Rural    34.62344
#  dtype: float64)

# %%
# 5. Get the average fare per driver for each city type. 

# calculate the average fare per driver by city type by dividing the 
# sum of all the fares by the total drivers.

avg_urban_driver_fare = urban_cities_df.groupby(["type"]).sum()["fare"]/ urban_drivers

avg_suburban_driver_fare = suburban_cities_df.groupby(["type"]).sum()["fare"]/ suburban_drivers

avg_rural_driver_fare = rural_cities_df.groupby(["type"]).sum()["fare"]/ rural_drivers

# Show avg fare per driver
avg_driver_fare = avg_urban_driver_fare,avg_suburban_driver_fare, avg_rural_driver_fare
avg_driver_fare
# Out:
# (type
#  Urban    0.668675
#  dtype: float64,
#  type
#  Suburban    2.258615
#  dtype: float64,
#  type
#  Rural    8.05946
#  dtype: float64)

# %%
#  6. Create a PyBer summary DataFrame. 

# create a PyBer summary DataFrame with all the data gathered from Steps 1-5, 
# using the column names: Total Rides, Total Drivers, Total Fares, Average Fare per Ride, Average Fare per Driver


# Adding a list of values with keys to create a new DataFrame.
pyber_summary_df = pd.DataFrame(
          {"Total Rides": total_rides,
          "Total Drivers": total_drivers,
          "Total Fares": total_fares,
          "Average Fare per Ride": avg_fare,
          "Average Fare per Driver": avg_driver_fare
          }, index = ["Urban","Suburban","Rural"])
pyber_summary_df
# Out:
#                                                Total Rides  \
# Urban       type
# Urban    1625
# Name: ride_id, dtype: int64
# Suburban  type
# Suburban    625
# Name: ride_id, dtype: int64
# Rural        type
# Rural    125
# Name: ride_id, dtype: int64
#
#                                               Total Drivers  \
# Urban     type
# Urban    59602
# Name: driver_count, dtype:...
# Suburban  type
# Suburban    8570
# Name: driver_count, dtyp...
# Rural     type
# Rural    537
# Name: driver_count, dtype: i...
#
#                                                 Total Fares  \
# Urban     type
# Urban    39854.38
# Name: fare, dtype: float64
# Suburban  type
# Suburban    19356.33
# Name: fare, dtype: f...
# Rural      type
# Rural    4327.93
# Name: fare, dtype: float64
#
#                               Average Fare per Ride  \
# Urban        type
# Urban    24.525772
# dtype: float64
# Suburban  type
# Suburban    30.970128
# dtype: float64
# Rural         type
# ...

# %%
#  7. Cleaning up the DataFrame. Delete the index name "type"
pyber_summary_df.index.name = None

pyber_summary_df
# Out:
#                                                Total Rides  \
# Urban       type
# Urban    1625
# Name: ride_id, dtype: int64
# Suburban  type
# Suburban    625
# Name: ride_id, dtype: int64
# Rural        type
# Rural    125
# Name: ride_id, dtype: int64
#
#                                               Total Drivers  \
# Urban     type
# Urban    59602
# Name: driver_count, dtype:...
# Suburban  type
# Suburban    8570
# Name: driver_count, dtyp...
# Rural     type
# Rural    537
# Name: driver_count, dtype: i...
#
#                                                 Total Fares  \
# Urban     type
# Urban    39854.38
# Name: fare, dtype: float64
# Suburban  type
# Suburban    19356.33
# Name: fare, dtype: f...
# Rural      type
# Rural    4327.93
# Name: fare, dtype: float64
#
#                               Average Fare per Ride  \
# Urban        type
# Urban    24.525772
# dtype: float64
# Suburban  type
# Suburban    30.970128
# dtype: float64
# Rural         type
# ...

# %%
#  8. Format the columns.
pyber_summary_df["Total Rides"] = pyber_summary_df["Total Rides"].map("{:,}".format)
pyber_summary_df["Total Drivers"] = pyber_summary_df["Total Drivers"].map("{:,}".format)
pyber_summary_df["Total Fares"] = pyber_summary_df["Total Fares"].map("${:,.2f}".format)
pyber_summary_df["Average Fare per Ride"] = pyber_summary_df["Average Fare per Ride"].map("${:,.2f}".format)
pyber_summary_df["Average Fare per Driver"] = pyber_summary_df["Average Fare per Driver"].map("${:,.2f}".format)

pyber_summary_df

# %% [markdown]
# ## Deliverable 2.  Create a multiple line plot that shows the total weekly of the fares for each type of city.

# %%
# 1. Read the merged DataFrame
pyber_data_df.head()
# Out:
#                  city                date   fare        ride_id  driver_count  \
# 0  Lake Jonathanshire 2019-01-14 10:14:22  13.83  5739410935873             5
# 1  South Michelleport 2019-03-04 18:24:09  30.24  2343912425577            72
# 2  Port Samanthamouth 2019-02-24 04:29:00  33.44  2005065760003            57
# 3          Rodneyfort 2019-02-10 23:22:03  23.44  5149245426178            34
# 4          South Jack 2019-03-06 04:28:35  34.58  3908451377344            46
#
#     type
# 0  Urban
# 1  Urban
# 2  Urban
# 3  Urban
# 4  Urban

# %%
# 2. Using groupby() to create a new DataFrame showing the sum of the fares 
#  for each date where the indices are the city type and date.
total_fare_per_day = pyber_data_df.groupby(['type','date']).sum()['fare']
total_fare_per_day
# Out:
# type   date
# Rural  2019-01-01 09:45:36    43.69
#        2019-01-02 11:18:32    52.12
#        2019-01-03 19:51:01    19.90
#        2019-01-04 03:31:26    24.88
#        2019-01-06 07:38:40    47.33
#                               ...
# Urban  2019-05-08 04:20:00    21.99
#        2019-05-08 04:39:49    18.45
#        2019-05-08 07:29:01    18.55
#        2019-05-08 11:38:35    19.77
#        2019-05-08 13:10:18    18.04
# Name: fare, Length: 2375, dtype: float64

# %%
# 3. Reset the index on the DataFrame you created in #1. This is needed to use the 'pivot()' function.
# df = df.reset_index()
total_fare_per_day = total_fare_per_day.reset_index()
total_fare_per_day.head()
# Out:
#     type                date   fare
# 0  Rural 2019-01-01 09:45:36  43.69
# 1  Rural 2019-01-02 11:18:32  52.12
# 2  Rural 2019-01-03 19:51:01  19.90
# 3  Rural 2019-01-04 03:31:26  24.88
# 4  Rural 2019-01-06 07:38:40  47.33

# %%
# 4. Create a pivot table with the 'date' as the index, the columns ='type', and values='fare' 
# to get the total fares for each type of city by the date. 
total_fare_per_day_pivot = total_fare_per_day.pivot(index='date', columns='type', values='fare')
total_fare_per_day_pivot
# Out:
# type                 Rural  Suburban  Urban
# date
# 2019-01-01 00:08:16    NaN       NaN  37.91
# 2019-01-01 00:46:46    NaN     47.74    NaN
# 2019-01-01 02:07:24    NaN     24.07    NaN
# 2019-01-01 03:46:50    NaN       NaN   7.57
# 2019-01-01 05:23:21    NaN       NaN  10.75
# ...                    ...       ...    ...
# 2019-05-08 04:20:00    NaN       NaN  21.99
# 2019-05-08 04:39:49    NaN       NaN  18.45
# 2019-05-08 07:29:01    NaN       NaN  18.55
# 2019-05-08 11:38:35    NaN       NaN  19.77
# 2019-05-08 13:10:18    NaN       NaN  18.04
#
# [2375 rows x 3 columns]

# %%
# 5. Create a new DataFrame from the pivot table DataFrame using loc on the given dates, '2019-01-01':'2019-04-29'.
jan_apr_fare_per_day = total_fare_per_day_pivot.loc['2019-01-01':'2019-04-29']
jan_apr_fare_per_day.tail()
# Out:
# type                 Rural  Suburban  Urban
# date
# 2019-04-29 20:54:19    NaN       NaN  28.41
# 2019-04-29 21:20:41    NaN       NaN  13.59
# 2019-04-29 22:08:22    NaN     25.75    NaN
# 2019-04-29 23:05:04    NaN       NaN  14.59
# 2019-04-29 23:10:18    NaN     29.39    NaN

# %%
# 6. Set the "date" index to datetime datatype. This is necessary to use the resample() method in Step 8.
# df.index = pd.to_datetime(df.index)
jan_apr_fare_per_day.index = pd.to_datetime(jan_apr_fare_per_day.index)

# %%
# 7. Check that the datatype for the index is datetime using df.info()
jan_apr_fare_per_day.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2218 entries, 2019-01-01 00:08:16 to 2019-04-29 23:10:18
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Rural     116 non-null    float64
#  1   Suburban  579 non-null    float64
#  2   Urban     1523 non-null   float64
# dtypes: float64(3)
# memory usage: 69.3 KB

# %%
# 8. Create a new DataFrame using the "resample()" function by week 'W' and get the sum of the fares for each week.
jan_apr_fare_per_week = jan_apr_fare_per_day.resample("W").sum()
jan_apr_fare_per_week.head()
# Out:
# type         Rural  Suburban    Urban
# date
# 2019-01-06  187.92    721.60  1661.68
# 2019-01-13   67.65   1105.13  2050.43
# 2019-01-20  306.00   1218.20  1939.02
# 2019-01-27  179.69   1203.28  2129.51
# 2019-02-03  333.08   1042.79  2086.94

# %%
# 8. Using the object-oriented interface method, plot the resample DataFrame using the df.plot() function. 
import matplotlib.dates as mdates

fig, ax = plt.subplots(figsize=(15, 6))
ax.plot(jan_apr_fare_per_week)
ax.set_ylabel('Fare ($USD)',fontsize=14)
ax.set_xticks(pd.date_range(start = "2019-01-01", end = "2019-04-29", freq="MS"))
ax.set_title("Total Fare by City Type")
# Make ticks on occurrences of each month:
ax.xaxis.set_major_locator(mdates.MonthLocator())
# Get only the month to show in the x-axis:
ax.xaxis.set_major_formatter(mdates.DateFormatter('%b'))
ax.legend(["Rural","Suburban","Urban"])

# Import the style from Matplotlib.
from matplotlib import style
# Use the graph style fivethirtyeight.
style.use('fivethirtyeight')
# Save the figure.
plt.savefig("analysis/PyBer_fare_summary.png")
